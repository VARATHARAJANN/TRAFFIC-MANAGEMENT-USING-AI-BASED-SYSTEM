# %% [markdown]
# **Import Libraries & Initialize Plots**

# %%
# Common libraries for data cleaning and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from numpy import load
from scipy.signal import periodogram
from sklearn.preprocessing import MinMaxScaler

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %%
plt.rcParams.update({'font.size': 12, 'font.family': 'serif'})
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['figure.dpi'] = 100
plt.rcParams['axes.grid'] = True
plt.rcParams['axes.grid.which'] = 'both'
plt.rcParams['grid.alpha'] = 0.5

# %% [markdown]
# **Data Formatting**

# %%
import pandas as pd

# Use pandas to read the compressed CSV file instead of numpy.load
data = pd.read_csv('/content/compressed_data.csv.gz')

# If you need the data as a NumPy array, use:
data = data.to_numpy()

# %%
import pandas as pd

# Use pandas to read the compressed CSV file instead of numpy.load
data = pd.read_csv('/content/compressed_data.csv.gz')

# Assign the DataFrame to a variable named df
df = pd.DataFrame(data)  # Assuming 'data' is a NumPy array or a list of lists

# Now you can use df.head()
df.head()
# Out:
#    timestep  location   flow  occupy  speed
# 0         1         0  133.0  0.0603   65.8
# 1         1         1  210.0  0.0589   69.6
# 2         1         2  124.0  0.0358   65.8
# 3         1         3  145.0  0.0416   69.6
# 4         1         4  206.0  0.0493   69.4

# %%
import pandas as pd

lst = df.columns
# Use .iloc for integer-location based indexing with DataFrames
print(df.iloc[:, df.columns.get_loc(lst[0])].shape)

print(df.iloc[:, df.columns.get_loc(lst[0])])
# Out:
# (3035520,)
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#            ...
# 3035515    17856
# 3035516    17856
# 3035517    17856
# 3035518    17856
# 3035519    17856
# Name: timestep, Length: 3035520, dtype: int64

# %%
import pandas as pd

# Assuming 'df' already contains the data you want to save
# If not, define 'df' with the appropriate data first

# Convert the DataFrame 'df' to a dictionary
data_dict = df.to_dict()

# Now create a new DataFrame from 'data_dict' if necessary
df = pd.DataFrame(data_dict)

# Save the DataFrame to a CSV file
df.to_csv("traffic.csv", index=False)

# %% [markdown]
# **Data Visualization & EDA**

# %%
traffic = pd.read_csv("/content/compressed_data.csv.gz")
print(len(traffic))
traffic.head()
# Out:
# 3035520
#    timestep  location   flow  occupy  speed
# 0         1         0  133.0  0.0603   65.8
# 1         1         1  210.0  0.0589   69.6
# 2         1         2  124.0  0.0358   65.8
# 3         1         3  145.0  0.0416   69.6
# 4         1         4  206.0  0.0493   69.4

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035520 entries, 0 to 3035519
# Data columns (total 5 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   timestep  int64
#  1   location  int64
#  2   flow      float64
#  3   occupy    float64
#  4   speed     float64
# dtypes: float64(3), int64(2)
# memory usage: 115.8 MB

# %%
traffic.count()
# Out:
# timestep    3035520
# location    3035520
# flow        3035520
# occupy      3035520
# speed       3035520
# dtype: int64

# %%
traffic.isna().sum()
# Out:
# timestep    0
# location    0
# flow        0
# occupy      0
# speed       0
# dtype: int64

# %%
traffic.describe()
# Out:
#            timestep      location          flow        occupy         speed
# count  3.035520e+06  3.035520e+06  3.035520e+06  3.035520e+06  3.035520e+06
# mean   8.928500e+03  8.450000e+01  2.306807e+02  6.507109e-02  6.376300e+01
# std    5.154584e+03  4.907393e+01  1.462170e+02  4.590215e-02  6.652010e+00
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  3.000000e+00
# 25%    4.464750e+03  4.200000e+01  1.100000e+02  3.570000e-02  6.260000e+01
# 50%    8.928500e+03  8.450000e+01  2.150000e+02  6.010000e-02  6.490000e+01
# 75%    1.339225e+04  1.270000e+02  3.340000e+02  8.390000e-02  6.740000e+01
# max    1.785600e+04  1.690000e+02  1.147000e+03  8.955000e-01  8.230000e+01

# %%
traffic['flow'].hist(bins=100);

# %%
traffic['occupy'].hist(bins=100);

# %%
traffic['speed'].hist(bins=100);

# %%
location_0 = traffic[traffic["location"]==50].reset_index()
location_0.head()
# Out:
#    index  timestep  location  flow  occupy  speed
# 0     50         1        50  76.0  0.0262   69.5
# 1    220         2        50  81.0  0.0255   68.8
# 2    390         3        50  80.0  0.0243   69.0
# 3    560         4        50  76.0  0.0255   68.4
# 4    730         5        50  70.0  0.0224   68.1

# %%
location_0["occupy"][:1000].plot()
# Out:
# <Axes: >

# %%
location_0["flow"][:1000].plot()
# Out:
# <Axes: >

# %%
location_0["speed"][:1000].plot();

# %%
COR_STEP = 1
pres = traffic[['flow', 'occupy', 'speed']][0:-(COR_STEP)].reset_index(drop=True)
future = traffic[['flow', 'occupy', 'speed']][COR_STEP:] \
    .reset_index(drop=True) \
    .add_suffix('_future')
val = pres.join(future)
val.corr()
# Out:
#                    flow    occupy     speed  flow_future  occupy_future  \
# flow           1.000000  0.674039 -0.296332     0.535235       0.450192
# occupy         0.674039  1.000000 -0.752040     0.445282       0.477379
# speed         -0.296332 -0.752040  1.000000    -0.228266      -0.275180
# flow_future    0.535235  0.445282 -0.228266     1.000000       0.674040
# occupy_future  0.450192  0.477379 -0.275180     0.674040       1.000000
# speed_future  -0.235030 -0.303858  0.233537    -0.296331      -0.752040
#
#                speed_future
# flow              -0.235030
# occupy            -0.303858
# speed              0.233537
# flow_future       -0.296331
# occupy_future     -0.752040
# speed_future       1.000000

# %%
def plot_periodogram(ts, detrend='linear', ax=None):
    """
    Plots the periodogram of a time series.

    Args:
        ts (pd.Series): A time series.
        detrend (str): Detrending method for the time series.
        ax (matplotlib.axes.Axes): The axes on which to plot.

    Returns:
        ax (matplotlib.axes.Axes): The axes on which the periodogram is plotted.
    """
    fs = pd.Timedelta(weeks=4) / pd.Timedelta(minutes=5)
    frequencies, spectrum = periodogram(
        ts,
        fs=fs,
        detrend=detrend,
        window="boxcar",
        scaling='spectrum',
    )
    if ax is None:
        _, ax = plt.subplots()

    ax.step(frequencies, spectrum, color="purple")
    ax.set_xscale("log")
    ax.set_xticks([4, 30, 30*24])
    ax.set_xticklabels(
        [
            "Weekly",
            "Daily",
            "Hourly"
        ],
        rotation=30,
    )
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0, 0))
    ax.set_ylabel("Variance")
    ax.set_title("Periodogram")
    return ax

plot_periodogram(location_0["occupy"])
# Out:
# <Axes: title={'center': 'Periodogram'}, ylabel='Variance'>

# %%
location_0["hour"] = ((location_0["timestep"] - 1) // 12)
grouped = location_0.groupby("hour").mean().reset_index()
grouped.head()
# Out:
#    hour   index  timestep  location       flow    occupy      speed
# 0     0   985.0       6.5      50.0  65.500000  0.021700  68.191667
# 1     1  3025.0      18.5      50.0  48.166667  0.016567  67.900000
# 2     2  5065.0      30.5      50.0  41.166667  0.016350  67.691667
# 3     3  7105.0      42.5      50.0  46.666667  0.019350  67.591667
# 4     4  9145.0      54.5      50.0  89.750000  0.031800  68.141667

# %%
grouped["occupy"][:24*5].plot();

# %%
COR_STEP = 12
pres = grouped[['flow', 'occupy', 'speed']][0:-(COR_STEP)].reset_index(drop=True)
future = grouped[['flow', 'occupy', 'speed']][COR_STEP:] \
    .reset_index(drop=True) \
    .add_suffix('_future')
val = pres.join(future)
val.corr()
# Out:
#                    flow    occupy     speed  flow_future  occupy_future  \
# flow           1.000000  0.966218 -0.718619    -0.722547      -0.707590
# occupy         0.966218  1.000000 -0.839110    -0.707282      -0.694619
# speed         -0.718619 -0.839110  1.000000     0.693508       0.681356
# flow_future   -0.722547 -0.707282  0.693508     1.000000       0.966046
# occupy_future -0.707590 -0.694619  0.681356     0.966046       1.000000
# speed_future   0.701991  0.686046 -0.599727    -0.718996      -0.839682
#
#                speed_future
# flow               0.701991
# occupy             0.686046
# speed             -0.599727
# flow_future       -0.718996
# occupy_future     -0.839682
# speed_future       1.000000

# %% [markdown]
# **Data Preparation**

# %%
# creating 3-dimensional array for [timestep, timeframe, features]
def create_dataset(location, WINDOW_SIZE):

    # mask a certain location
    location_current = traffic[traffic["location"]==location].reset_index()

    # group to hour and average 12 (5-minute) timesteps
    location_current["hour"] = ((location_current["timestep"] - 1) // 12)
    grouped = location_current.groupby("hour").mean().reset_index()

    # add hour features as mod 24 cycle (0...23)
    grouped['day'] = (grouped['hour'] // 24) % 7
    grouped['hour'] %= 24

    one_hot_hour = pd.get_dummies(grouped['hour'])
    one_hot_hour = one_hot_hour.add_prefix('hour_')

    # merge all the features together to get a total of 27 features
    hour_grouped = pd.concat([grouped[["occupy", "flow", "speed"]], one_hot_hour], axis=1)
    hour_grouped = np.array(hour_grouped)

    X, Y = [], []

    # add lag features (in reverse time order)
    for i in range(len(hour_grouped) - WINDOW_SIZE):
        X.append(hour_grouped[i:(i + WINDOW_SIZE)][::-1]) # reverse the order
        Y.append(hour_grouped[i + WINDOW_SIZE, 0]) # index 0 is occupy

    return X,Y # returns (timestep, timeframe, features) and (target)

# %%
# creating 4-th dimension for the locations
X, Y = [], []

for location in range(170):
    a,b = create_dataset(location, WINDOW_SIZE=24)
    X.append(a)
    Y.append(b)

X = np.moveaxis(X,0,-1)
Y = np.moveaxis(Y,0,-1)

print(X.shape)
print(Y.shape)
# Out:
# (1464, 24, 27, 170)
# (1464, 170)

# %%
TEST_SIZE  = 0.2
TRAIN_SIZE = 0.8 # Add this line to define TRAIN_SIZE

train_size = int(len(X) * TRAIN_SIZE)
test_size  = int(len(X) * TEST_SIZE)

train_X, train_Y = X[:train_size], Y[:train_size]
test_X, test_Y = X[train_size:], Y[train_size:]

print(train_X.shape)
print(train_Y.shape)
print(test_X.shape)
print(test_Y.shape)
# Out:
# (1171, 24, 27, 170)
# (1171, 170)
# (293, 24, 27, 170)
# (293, 170)

# %%
scaler_X = MinMaxScaler()
scaler_Y = MinMaxScaler()
train_X = scaler_X.fit_transform(train_X.reshape(train_X.shape[0] * train_X.shape[1], -1)) \
                   .reshape(train_X.shape[0], train_X.shape[1], -1)
test_X = scaler_X.transform(test_X.reshape(test_X.shape[0] * test_X.shape[1], -1)) \
                   .reshape(test_X.shape[0], test_X.shape[1], -1)
train_Y = scaler_Y.fit_transform(train_Y)
test_Y = scaler_Y.transform(test_Y)

# %%
print(train_X.shape)
print(test_X.shape)
print(train_Y.shape)
print(test_Y.shape)
# Out:
# (1171, 24, 4590)
# (293, 24, 4590)
# (1171, 170)
# (293, 170)

# %% [markdown]
# **Model Training**

# %%
# !pip install tensorflow

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.metrics import RootMeanSquaredError # Import RootMeanSquaredError

model = Sequential([
    LSTM(256, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])),
    LSTM(256, return_sequences=False),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(170, activation='linear'),
])

model.compile(loss='mse', optimizer='adam', metrics=[RootMeanSquaredError()]) # Now RootMeanSquaredError is defined
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 24, 256)             │       4,963,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 256)                 │         525,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 170)                 │          43,690 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,598,122 (21.36 MB)
#  Trainable params: 5,598,122 (21.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model  # Import plot_model from tensorflow.keras.utils

plot_model(model, show_shapes=True, show_layer_names=True)

# %%
# Train the model
history = model.fit(train_X, train_Y, epochs=150, batch_size=32, validation_split=0.1, verbose=2)
# Out:
# Epoch 1/150
# 33/33 - 28s - 860ms/step - loss: 0.0393 - root_mean_squared_error: 0.1982 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1299
# Epoch 2/150
# 33/33 - 44s - 1s/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1241
# Epoch 3/150
# 33/33 - 24s - 730ms/step - loss: 0.0117 - root_mean_squared_error: 0.1082 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1078
# Epoch 4/150
# 33/33 - 39s - 1s/step - loss: 0.0092 - root_mean_squared_error: 0.0961 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1031
# Epoch 5/150
# 33/33 - 42s - 1s/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0982
# Epoch 6/150
# 33/33 - 43s - 1s/step - loss: 0.0070 - root_mean_squared_error: 0.0837 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0962
# Epoch 7/150
# 33/33 - 39s - 1s/step - loss: 0.0066 - root_mean_squared_error: 0.0813 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0967
# Epoch 8/150
# 33/33 - 43s - 1s/step - loss: 0.0064 - root_mean_squared_error: 0.0799 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 9/150
# 33/33 - 21s - 651ms/step - loss: 0.0061 - root_mean_squared_error: 0.0783 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0971
# Epoch 10/150
# 33/33 - 25s - 757ms/step - loss: 0.0060 - root_mean_squared_error: 0.0778 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 11/150
# 33/33 - 21s - 642ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0941
# Epoch 12/150
# 33/33 - 43s - 1s/step - loss: 0.0055 - root_mean_squared_error: 0.0740 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0933
# Epoch 13/150
# 33/33 - 42s - 1s/step - loss: 0.0054 - root_mean_squared_error: 0.0733 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0958
# Epoch 14/150
# 33/33 - 42s - 1s/step - loss: 0.0052 - root_mean_squared_error: 0.0723 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 15/150
# 33/33 - 22s - 661ms/step - loss: 0.0052 - root_mean_squared_error: 0.0720 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0932
# Epoch 16/150
# 33/33 - 41s - 1s/step - loss: 0.0051 - root_mean_squared_error: 0.0717 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0938
# Epoch 17/150
# 33/33 - 42s - 1s/step - loss: 0.0049 - root_mean_squared_error: 0.0700 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0917
# Epoch 18/150
# 33/33 - 43s - 1s/step - loss: 0.0049 - root_mean_squared_error: 0.0703 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0925
# Epoch 19/150
# 33/33 - 22s - 661ms/step - loss: 0.0047 - root_mean_squared_error: 0.0688 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0950
# Epoch 20/150
# 33/33 - 24s - 722ms/step - loss: 0.0046 - root_mean_squared_error: 0.0677 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0913
# Epoch 21/150
# 33/33 - 22s - 653ms/step - loss: 0.0046 - root_mean_squared_error: 0.0679 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0926
# Epoch 22/150
# 33/33 - 43s - 1s/step - loss: 0.0046 - root_mean_squared_error: 0.0678 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0927
# Epoch 23/150
# 33/33 - 43s - 1s/step - loss: 0.0045 - root_mean_squared_error: 0.0668 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0923
# Epoch 24/150
# 33/33 - 22s - 659ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0905
# Epoch 25/150
# 33/33 - 24s - 714ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0906
# Epoch 26/150
# 33/33 - 41s - 1s/step - loss: 0.0042 - root_mean_squared_error: 0.0648 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0923
# Epoch 27/150
# 33/33 - 43s - 1s/step - loss: 0.0043 - root_mean_squared_error: 0.0653 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0940
# Epoch 28/150
# 33/33 - 39s - 1s/step - loss: 0.0041 - root_mean_squared_error: 0.0643 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0918
# Epoch 29/150
# 33/33 - 42s - 1s/step - loss: 0.0041 - root_mean_squared_error: 0.0643 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0913
# Epoch 30/150
# 33/33 - 41s - 1s/step - loss: 0.0042 - root_mean_squared_error: 0.0646 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0918
# Epoch 31/150
# 33/33 - 25s - 747ms/step - loss: 0.0040 - root_mean_squared_error: 0.0636 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0900
# Epoch 32/150
# 33/33 - 39s - 1s/step - loss: 0.0040 - root_mean_squared_error: 0.0633 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0909
# Epoch 33/150
# 33/33 - 41s - 1s/step - loss: 0.0040 - root_mean_squared_error: 0.0629 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0920
# Epoch 34/150
# 33/33 - 43s - 1s/step - loss: 0.0040 - root_mean_squared_error: 0.0632 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0890
# Epoch 35/150
# 33/33 - 25s - 755ms/step - loss: 0.0039 - root_mean_squared_error: 0.0624 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0900
# Epoch 36/150
# 33/33 - 23s - 710ms/step - loss: 0.0040 - root_mean_squared_error: 0.0631 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0909
# Epoch 37/150
# 33/33 - 41s - 1s/step - loss: 0.0039 - root_mean_squared_error: 0.0626 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0895
# Epoch 38/150
# 33/33 - 42s - 1s/step - loss: 0.0038 - root_mean_squared_error: 0.0617 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0905
# Epoch 39/150
# 33/33 - 43s - 1s/step - loss: 0.0038 - root_mean_squared_error: 0.0614 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0918
# Epoch 40/150
# 33/33 - 39s - 1s/step - loss: 0.0038 - root_mean_squared_error: 0.0617 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0901
# Epoch 41/150
# 33/33 - 22s - 682ms/step - loss: 0.0039 - root_mean_squared_error: 0.0622 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0903
# Epoch 42/150
# 33/33 - 43s - 1s/step - loss: 0.0038 - root_mean_squared_error: 0.0616 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0896
# Epoch 43/150
# 33/33 - 43s - 1s/step - loss: 0.0038 - root_mean_squared_error: 0.0617 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0886
# Epoch 44/150
# 33/33 - 39s - 1s/step - loss: 0.0037 - root_mean_squared_error: 0.0610 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0887
# Epoch 45/150
# 33/33 - 40s - 1s/step - loss: 0.0036 - root_mean_squared_error: 0.0602 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0895
# Epoch 46/150
# 33/33 - 42s - 1s/step - loss: 0.0036 - root_mean_squared_error: 0.0600 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0895
# Epoch 47/150
# 33/33 - 25s - 752ms/step - loss: 0.0036 - root_mean_squared_error: 0.0603 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 48/150
# 33/33 - 39s - 1s/step - loss: 0.0036 - root_mean_squared_error: 0.0600 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0920
# Epoch 49/150
# 33/33 - 41s - 1s/step - loss: 0.0035 - root_mean_squared_error: 0.0595 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0869
# Epoch 50/150
# 33/33 - 42s - 1s/step - loss: 0.0036 - root_mean_squared_error: 0.0599 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0885
# Epoch 51/150
# 33/33 - 41s - 1s/step - loss: 0.0035 - root_mean_squared_error: 0.0592 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0888
# Epoch 52/150
# 33/33 - 43s - 1s/step - loss: 0.0034 - root_mean_squared_error: 0.0587 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0883
# Epoch 53/150
# 33/33 - 39s - 1s/step - loss: 0.0035 - root_mean_squared_error: 0.0595 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 54/150
# 33/33 - 42s - 1s/step - loss: 0.0035 - root_mean_squared_error: 0.0589 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0881
# Epoch 55/150
# 33/33 - 40s - 1s/step - loss: 0.0034 - root_mean_squared_error: 0.0585 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0876
# Epoch 56/150
# 33/33 - 44s - 1s/step - loss: 0.0034 - root_mean_squared_error: 0.0584 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0877
# Epoch 57/150
# 33/33 - 38s - 1s/step - loss: 0.0035 - root_mean_squared_error: 0.0587 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0892
# Epoch 58/150
# 33/33 - 27s - 806ms/step - loss: 0.0035 - root_mean_squared_error: 0.0588 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0886
# Epoch 59/150
# 33/33 - 25s - 756ms/step - loss: 0.0034 - root_mean_squared_error: 0.0584 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 60/150
# 33/33 - 41s - 1s/step - loss: 0.0033 - root_mean_squared_error: 0.0574 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0867
# Epoch 61/150
# 33/33 - 23s - 695ms/step - loss: 0.0033 - root_mean_squared_error: 0.0573 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 62/150
# 33/33 - 43s - 1s/step - loss: 0.0033 - root_mean_squared_error: 0.0571 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0876
# Epoch 63/150
# 33/33 - 40s - 1s/step - loss: 0.0034 - root_mean_squared_error: 0.0579 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0877
# Epoch 64/150
# 33/33 - 43s - 1s/step - loss: 0.0033 - root_mean_squared_error: 0.0573 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0877
# Epoch 65/150
# 33/33 - 40s - 1s/step - loss: 0.0033 - root_mean_squared_error: 0.0570 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0875
# Epoch 66/150
# 33/33 - 42s - 1s/step - loss: 0.0033 - root_mean_squared_error: 0.0573 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 67/150
# 33/33 - 24s - 721ms/step - loss: 0.0032 - root_mean_squared_error: 0.0568 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0883
# Epoch 68/150
# 33/33 - 40s - 1s/step - loss: 0.0033 - root_mean_squared_error: 0.0573 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 69/150
# 33/33 - 41s - 1s/step - loss: 0.0032 - root_mean_squared_error: 0.0566 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 70/150
# 33/33 - 44s - 1s/step - loss: 0.0031 - root_mean_squared_error: 0.0560 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 71/150
# 33/33 - 38s - 1s/step - loss: 0.0032 - root_mean_squared_error: 0.0565 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0889
# Epoch 72/150
# 33/33 - 24s - 720ms/step - loss: 0.0032 - root_mean_squared_error: 0.0566 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0865
# Epoch 73/150
# 33/33 - 41s - 1s/step - loss: 0.0031 - root_mean_squared_error: 0.0559 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 74/150
# 33/33 - 44s - 1s/step - loss: 0.0031 - root_mean_squared_error: 0.0561 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 75/150
# 33/33 - 39s - 1s/step - loss: 0.0032 - root_mean_squared_error: 0.0563 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0869
# Epoch 76/150
# 33/33 - 23s - 710ms/step - loss: 0.0031 - root_mean_squared_error: 0.0556 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 77/150
# 33/33 - 42s - 1s/step - loss: 0.0030 - root_mean_squared_error: 0.0550 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0867
# Epoch 78/150
# 33/33 - 41s - 1s/step - loss: 0.0031 - root_mean_squared_error: 0.0556 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0888
# Epoch 79/150
# 33/33 - 23s - 710ms/step - loss: 0.0031 - root_mean_squared_error: 0.0554 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0865
# Epoch 80/150
# 33/33 - 24s - 742ms/step - loss: 0.0031 - root_mean_squared_error: 0.0554 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 81/150
# 33/33 - 23s - 695ms/step - loss: 0.0031 - root_mean_squared_error: 0.0556 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0876
# Epoch 82/150
# 33/33 - 43s - 1s/step - loss: 0.0031 - root_mean_squared_error: 0.0553 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 83/150
# 33/33 - 43s - 1s/step - loss: 0.0030 - root_mean_squared_error: 0.0550 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 84/150
# 33/33 - 23s - 703ms/step - loss: 0.0031 - root_mean_squared_error: 0.0555 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0881
# Epoch 85/150
# 33/33 - 41s - 1s/step - loss: 0.0030 - root_mean_squared_error: 0.0551 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 86/150
# 33/33 - 44s - 1s/step - loss: 0.0031 - root_mean_squared_error: 0.0554 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0874
# Epoch 87/150
# 33/33 - 42s - 1s/step - loss: 0.0030 - root_mean_squared_error: 0.0547 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0889
# Epoch 88/150
# 33/33 - 39s - 1s/step - loss: 0.0031 - root_mean_squared_error: 0.0554 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0883
# Epoch 89/150
# 33/33 - 42s - 1s/step - loss: 0.0030 - root_mean_squared_error: 0.0552 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 90/150
# 33/33 - 41s - 1s/step - loss: 0.0031 - root_mean_squared_error: 0.0559 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0867
# Epoch 91/150
# 33/33 - 42s - 1s/step - loss: 0.0030 - root_mean_squared_error: 0.0548 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0865
# Epoch 92/150
# 33/33 - 38s - 1s/step - loss: 0.0030 - root_mean_squared_error: 0.0543 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0874
# Epoch 93/150
# 33/33 - 41s - 1s/step - loss: 0.0030 - root_mean_squared_error: 0.0544 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0874
# Epoch 94/150
# 33/33 - 24s - 717ms/step - loss: 0.0029 - root_mean_squared_error: 0.0542 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0854
# Epoch 95/150
# 33/33 - 42s - 1s/step - loss: 0.0030 - root_mean_squared_error: 0.0547 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 96/150
# 33/33 - 39s - 1s/step - loss: 0.0029 - root_mean_squared_error: 0.0539 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0863
# Epoch 97/150
# 33/33 - 41s - 1s/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0861
# Epoch 98/150
# 33/33 - 43s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0532 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 99/150
# 33/33 - 39s - 1s/step - loss: 0.0029 - root_mean_squared_error: 0.0541 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 100/150
# 33/33 - 42s - 1s/step - loss: 0.0029 - root_mean_squared_error: 0.0540 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0879
# Epoch 101/150
# 33/33 - 23s - 691ms/step - loss: 0.0029 - root_mean_squared_error: 0.0540 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0863
# Epoch 102/150
# 33/33 - 41s - 1s/step - loss: 0.0029 - root_mean_squared_error: 0.0535 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 103/150
# 33/33 - 42s - 1s/step - loss: 0.0029 - root_mean_squared_error: 0.0542 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0867
# Epoch 104/150
# 33/33 - 40s - 1s/step - loss: 0.0029 - root_mean_squared_error: 0.0543 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 105/150
# 33/33 - 43s - 1s/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0854
# Epoch 106/150
# 33/33 - 39s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0532 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0857
# Epoch 107/150
# 33/33 - 26s - 775ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0875
# Epoch 108/150
# 33/33 - 39s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0529 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 109/150
# 33/33 - 41s - 1s/step - loss: 0.0029 - root_mean_squared_error: 0.0534 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 110/150
# 33/33 - 25s - 748ms/step - loss: 0.0028 - root_mean_squared_error: 0.0532 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 111/150
# 33/33 - 27s - 818ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0875
# Epoch 112/150
# 33/33 - 38s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0529 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 113/150
# 33/33 - 41s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0530 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0861
# Epoch 114/150
# 33/33 - 24s - 727ms/step - loss: 0.0028 - root_mean_squared_error: 0.0525 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0867
# Epoch 115/150
# 33/33 - 41s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0530 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0850
# Epoch 116/150
# 33/33 - 41s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0526 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0875
# Epoch 117/150
# 33/33 - 40s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0530 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0857
# Epoch 118/150
# 33/33 - 42s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0524 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0852
# Epoch 119/150
# 33/33 - 44s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0526 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 120/150
# 33/33 - 38s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0528 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 121/150
# 33/33 - 42s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0529 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 122/150
# 33/33 - 39s - 1s/step - loss: 0.0029 - root_mean_squared_error: 0.0534 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0888
# Epoch 123/150
# 33/33 - 44s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0534 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0877
# Epoch 124/150
# 33/33 - 38s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0526 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 125/150
# 33/33 - 41s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0528 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0856
# Epoch 126/150
# 33/33 - 24s - 713ms/step - loss: 0.0027 - root_mean_squared_error: 0.0523 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0852
# Epoch 127/150
# 33/33 - 25s - 754ms/step - loss: 0.0028 - root_mean_squared_error: 0.0525 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0867
# Epoch 128/150
# 33/33 - 41s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0524 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 129/150
# 33/33 - 23s - 682ms/step - loss: 0.0027 - root_mean_squared_error: 0.0519 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0854
# Epoch 130/150
# 33/33 - 42s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0519 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0869
# Epoch 131/150
# 33/33 - 43s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0523 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 132/150
# 33/33 - 41s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0519 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 133/150
# 33/33 - 41s - 1s/step - loss: 0.0028 - root_mean_squared_error: 0.0528 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 134/150
# 33/33 - 40s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0517 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0850
# Epoch 135/150
# 33/33 - 43s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0519 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 136/150
# 33/33 - 38s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0520 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 137/150
# 33/33 - 42s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0517 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 138/150
# 33/33 - 41s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0517 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0882
# Epoch 139/150
# 33/33 - 44s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 140/150
# 33/33 - 37s - 1s/step - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0863
# Epoch 141/150
# 33/33 - 42s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 142/150
# 33/33 - 23s - 697ms/step - loss: 0.0026 - root_mean_squared_error: 0.0515 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0856
# Epoch 143/150
# 33/33 - 25s - 745ms/step - loss: 0.0026 - root_mean_squared_error: 0.0515 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 144/150
# 33/33 - 25s - 761ms/step - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 145/150
# 33/33 - 40s - 1s/step - loss: 0.0026 - root_mean_squared_error: 0.0512 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 146/150
# 33/33 - 41s - 1s/step - loss: 0.0026 - root_mean_squared_error: 0.0507 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0851
# Epoch 147/150
# 33/33 - 41s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0517 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 148/150
# 33/33 - 41s - 1s/step - loss: 0.0027 - root_mean_squared_error: 0.0515 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 149/150
# 33/33 - 41s - 1s/step - loss: 0.0026 - root_mean_squared_error: 0.0513 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0863
# Epoch 150/150
# 33/33 - 41s - 1s/step - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0852

# %%
def plot_training(training_history, text, width):
    history = training_history.history[text]

    # creates a moving average plot to reduce variations
    moving_average = [float("NaN") for i in range(width)]
    for i in range(width, len(history)+1):
        moving_average.append(np.mean(np.array(history[i-width:i+1])))

    plt.plot(history)
    plt.plot(moving_average)
    plt.title(text)
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['value','moving average'], loc='upper left')
    plt.show()

# %%
# Plots the loss (MSE and RMSE) of both test and validation data
WIDTH = 10
plot_training(history,'loss',WIDTH)
plot_training(history,'val_loss',WIDTH)
plot_training(history,'val_root_mean_squared_error',WIDTH)
plot_training(history,'root_mean_squared_error',WIDTH)

# %% [markdown]
# **Evaluate Prediction**

# %%
def predict_and_calc_score(X, Y):
    # prediction of Y using the model
    pred = model.predict(X)
    # moving average of Y
    window_size = 12
    moving_average = np.apply_along_axis(
        lambda x: np.convolve(x, np.ones(window_size)/window_size, mode='same'), axis=0, arr=Y)
    moving_average = np.concatenate((np.zeros((1, Y.shape[1])), moving_average), axis=0)[:Y.shape[0]]

    # scale it back to the original scale
    pred_scaled = scaler_Y.inverse_transform(pred)
    moving_average_scaled = scaler_Y.inverse_transform(moving_average)
    Y_scaled = scaler_Y.inverse_transform(Y)

    # calculate the RMSE
    baseline_RMSE = np.sqrt(np.mean((Y_scaled - moving_average_scaled) ** 2))
    model_RMSE = np.sqrt(np.mean((Y_scaled - pred_scaled) ** 2))

    return Y_scaled, pred_scaled, moving_average_scaled, model_RMSE, baseline_RMSE

def plot_prediction(actual, prediction, moving_average):
    # Plot the actual values
    plt.plot(actual, label="True value", linestyle='-', linewidth=1, marker='s', markersize=1)

    # Plot the moving average
    plt.plot(moving_average, label="Moving Average", linestyle='--', linewidth=1, marker='s', markersize=1)

    # Plot the predicted values
    plt.plot(prediction, label="Prediction", linestyle='--', linewidth=1, marker='o', markersize=1)

    # Set the title and axis labels
    plt.title('Prediction vs. True Value', fontsize=16)
    plt.xlabel('Hour Timesteps')
    plt.ylabel('Output Value')

    # Add a legend to the plot
    plt.legend(loc='upper left', fontsize=12)

    # Display the plot
    plt.show()

# %%
import scipy.stats as stats # import the stats module from scipy

train_actual, train_prediction, train_moving_average, train_RMSE, baseline_RMSE = \
    predict_and_calc_score(train_X, train_Y)

print("Train Moving Average RMSE:", baseline_RMSE)
print("Train Prediction RMSE:", train_RMSE)

# calculate the spearman correlation using the imported stats module
corr, pval = stats.spearmanr(train_actual, train_moving_average)
mov_spearman_corr = np.mean(corr)
corr, pval = stats.spearmanr(train_actual, train_prediction)
pred_spearman_corr = np.mean(corr)

print("Train Moving Average Spearman Correlation:", mov_spearman_corr)
print("Train Prediction Spearman Correlation:", pred_spearman_corr)
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 12s 298ms/step
# Train Moving Average RMSE: 0.02385027817581988
# Train Prediction RMSE: 0.014404085870208435
# Train Moving Average Spearman Correlation: 0.7151104315867319
# Train Prediction Spearman Correlation: 0.8058967596220419

# %%
location = 3
plot_prediction(train_actual[:,location], train_prediction[:,location], train_moving_average[:,location])

# %%
test_actual, test_prediction, test_moving_average, test_RMSE, baseline_RMSE = \
    predict_and_calc_score(test_X, test_Y)

print("Test Moving Average RMSE:", baseline_RMSE)
print("Test Prediction RMSE:", test_RMSE)

corr, pval = stats.spearmanr(test_actual, test_moving_average)
mov_spearman_corr = np.mean(corr)
corr, pval = stats.spearmanr(test_actual, test_prediction)
pred_spearman_corr = np.mean(corr)

print("Test Moving Average Spearman Correlation:", mov_spearman_corr)
print("Test Prediction Spearman Correlation:", pred_spearman_corr)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 227ms/step
# Test Moving Average RMSE: 0.026519227318993185
# Test Prediction RMSE: 0.019653231518452396
# Test Moving Average Spearman Correlation: 0.7208934552099153
# Test Prediction Spearman Correlation: 0.8195992045825237

# %%
location = 10
plot_prediction(test_actual[:,location], test_prediction[:,location], test_moving_average[:,location])

# %%
model.save('LSTM_model.keras') # Change this line

# %%
# !zip -r LSTM_Model.zip /kaggle/working/LSTM_model
# Out:
# 	zip warning: name not matched: /kaggle/working/LSTM_model
#
# zip error: Nothing to do! (try: zip -r LSTM_Model.zip . -i /kaggle/working/LSTM_model)
